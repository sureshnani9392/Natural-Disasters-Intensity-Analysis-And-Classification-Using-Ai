# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen=ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True)

test_datagen=ImageDataGenerator(rescale=1./255)

# %%
x_train=train_datagen.flow_from_directory('/content/drive/MyDrive/ndm project/dataset/train_set',target_size=(64,64),batch_size=5,color_mode='rgb',class_mode='categorical')

x_test=test_datagen.flow_from_directory('/content/drive/MyDrive/ndm project/dataset/test_set',target_size=(64,64),batch_size=5,color_mode='rgb',class_mode='categorical')
# Out:
# Found 742 images belonging to 4 classes.
# Found 198 images belonging to 4 classes.

# %%
from keras.backend import flatten
import numpy as np
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense,Flatten
from tensorflow.keras.layers import Conv2D,MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator

# %%
model=Sequential()

# %%
model.add(Conv2D(32,(3,3),input_shape=(64,64,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(32,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())

# %%
model.add(Dense(units=128,activation='relu'))
model.add(Dense(units=4,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 62, 62, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 128)               802944
#
#  dense_1 (Dense)             (None, 4)                 516
#
# ...
# Total params: 813,604
# Trainable params: 813,604
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit_generator(generator=x_train,steps_per_epoch=len(x_train),epochs=20,validation_data=x_test,validation_steps=len(x_test))
# Out:
# <ipython-input-21-829d28d0ec8f>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(generator=x_train,steps_per_epoch=len(x_train),epochs=20,validation_data=x_test,validation_steps=len(x_test))
# Epoch 1/20
# 149/149 [==============================] - 274s 2s/step - loss: 1.1740 - accuracy: 0.4704 - val_loss: 1.0725 - val_accuracy: 0.5707
# Epoch 2/20
# 149/149 [==============================] - 30s 199ms/step - loss: 0.8473 - accuracy: 0.6509 - val_loss: 0.7057 - val_accuracy: 0.7626
# Epoch 3/20
# 149/149 [==============================] - 27s 182ms/step - loss: 0.7457 - accuracy: 0.7008 - val_loss: 0.9699 - val_accuracy: 0.5707
# Epoch 4/20
# 149/149 [==============================] - 26s 177ms/step - loss: 0.7062 - accuracy: 0.7291 - val_loss: 0.6813 - val_accuracy: 0.7576
# Epoch 5/20
# ...

# %%
model.save('disaster.h5')

# %%
model_json=model.to_json()
with open ("model-bw.json","w") as json_file:
  json_file.write(model_json)

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
model = load_model("disaster.h5")

# %%
img=image.load_img(r"/content/drive/MyDrive/ndm project/dataset/test_set/Earthquake/1345.jpg",target_size=(64,64))
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
pred=model.predict(x)
pred
# Out:
# 1/1 [==============================] - 0s 138ms/step
# array([[0., 1., 0., 0.]], dtype=float32)

# %%
index = ['Cyclone', 'Earthquake', 'Flood', 'Wildfire']

# Assuming pred is a non-integer value, extract the integer value
# Example: pred = [2] or pred = np.array([2])
pred = pred[0]  # Extracting the first element assuming it's an integer index

# Convert pred to an integer if it's not already
try:
    pred = int(pred)
    result = str(index[pred])
    print(result)
except ValueError:
    print("Error: pred is not a valid integer.")
# Out:
# Cyclone
